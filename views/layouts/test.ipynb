# %%
a = [1,3,5,7,9]

# %%
b = 0
c = len(a)-1

# %%
d = int((b+c)/2)

# %%
d
# Out:
# 2

# %%
m =-1

# %%
k = 5

# %%
while(b < d):
    if(k == a[d]): m=d
    elif (k > a[d]): 
        b = d
        d = (b+c)/2
    else :
        c = d 
        d = (b+c)/2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\defaultuser0.DESKTOP-MD45Q2R\Documents\test2\views\layouts\test.ipynb Cell 7 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.DESKTOP-MD45Q2R/Documents/test2/views/layouts/test.ipynb#X26sZmlsZQ%3D%3D?line=0'>1</a> while(b < d):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.DESKTOP-MD45Q2R/Documents/test2/views/layouts/test.ipynb#X26sZmlsZQ%3D%3D?line=1'>2</a>     if(k == a[d]): m=d
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.DESKTOP-MD45Q2R/Documents/test2/views/layouts/test.ipynb#X26sZmlsZQ%3D%3D?line=2'>3</a>     elif (k > a[d]):
#       <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.DESKTOP-MD45Q2R/Documents/test2/views/layouts/test.ipynb#X26sZmlsZQ%3D%3D?line=3'>4</a>         b = d
#
# KeyboardInterrupt:

# %%
s = 'aabbdd'

# %%
k = len(s)

# %%
n=0

# %%
while(len(s) > 0):
    m = s[0]
    s = s.strip(s[0])
    if (k - len(s) == 1): 
        n = m 
        break
    k = len(s)

# %%
n
# Out:
# 0

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\defaultuser0.DESKTOP-MD45Q2R\Documents\test2\views\layouts\test.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/defaultuser0.DESKTOP-MD45Q2R/Documents/test2/views/layouts/test.ipynb#X46sZmlsZQ%3D%3D?line=0'>1</a> typeof(n)
#
# NameError: name 'typeof' is not defined
